# %% [markdown]
# <a href="https://colab.research.google.com/github/alexiej/laboratory/blob/master/07_rapids_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Environment Sanity Check #
#
# Click the _Runtime_ dropdown at the top of the page, then _Change Runtime Type_ and confirm the instance type is _GPU_.
#
# Check the output of `!nvidia-smi` to make sure you've been allocated a Tesla T4 or P100.

# %%
# !nvidia-smi
# Out:
# Tue Nov 26 14:18:51 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.33.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# #Setup:
# Set up script installs
# 1. Install most recent Miniconda release compatible with Google Colab's Python install  (3.6.7)
# 1. removes incompatible files
# 1. Install RAPIDS libraries
# 1. Set necessary environment variables
# 1. Copy RAPIDS .so files into current working directory, a workaround for conda/colab interactions
# 1. If running v0.11 or higher, updates pyarrow library to 0.15.x.

# %%
# !wget -nc https://github.com/rapidsai/notebooks-extended/raw/master/utils/rapids-colab.sh
# !bash rapids-colab.sh

import sys, os

dist_package_index = sys.path.index("/usr/local/lib/python3.6/dist-packages")
sys.path = sys.path[:dist_package_index] + ["/usr/local/lib/python3.6/site-packages"] + sys.path[dist_package_index:]
# Out:
# --2019-11-26 14:18:54--  https://github.com/rapidsai/notebooks-extended/raw/master/utils/rapids-colab.sh
# Resolving github.com (github.com)... 140.82.118.4
# Connecting to github.com (github.com)|140.82.118.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/rapidsai/notebooks-contrib/raw/master/utils/rapids-colab.sh [following]
# --2019-11-26 14:18:54--  https://github.com/rapidsai/notebooks-contrib/raw/master/utils/rapids-colab.sh
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/rapidsai/notebooks-contrib/master/utils/rapids-colab.sh [following]
# --2019-11-26 14:18:55--  https://raw.githubusercontent.com/rapidsai/notebooks-contrib/master/utils/rapids-colab.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2262 (2.2K) [text/plain]
# Saving to: ‘rapids-colab.sh’
#
# rapids-colab.sh     100%[===================>]   2.21K  --.-KB/s    in 0s
#
# 2019-11-26 14:18:55 (76.1 MB/s) - ‘rapids-colab.sh’ saved [2262/2262]
#
# --2019-11-26 14:18:57--  https://github.com/rapidsai/notebooks-contrib/raw/master/utils/env-check.py
# Resolving github.com (github.com)... 140.82.118.4
# Connecting to github.com (github.com)|140.82.118.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/rapidsai/notebooks-contrib/master/utils/env-check.py [following]
# --2019-11-26 14:18:57--  https://raw.githubusercontent.com/rapidsai/notebooks-contrib/master/utils/env-check.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 918 [text/plain]
# Saving to: ‘env-check.py’
#
# env-check.py        100%[===================>]     918  --.-KB/s    in 0s
#
# 2019-11-26 14:18:57 (212 MB/s) - ‘env-check.py’ saved [918/918]
#
# Checking for GPU type:
# ***********************************************************************
# Woo! Your instance has the right kind of GPU, a 'Tesla P100-PCIE-16GB'!
# ***********************************************************************
#
# Removing conflicting packages, will replace with RAPIDS compatible versions
# Uninstalling xgboost-0.90:
#   Successfully uninstalled xgboost-0.90
# Uninstalling dask-1.1.5:
#   Successfully uninstalled dask-1.1.5
# Uninstalling distributed-1.25.3:
#   Successfully uninstalled distributed-1.25.3
# Installing conda
# --2019-11-26 14:19:01--  https://repo.continuum.io/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.201.79, 104.18.200.79, 2606:4700::6812:c94f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.201.79|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58468498 (56M) [application/x-sh]
# Saving to: ‘Miniconda3-4.5.4-Linux-x86_64.sh’
#
# Miniconda3-4.5.4-Li 100%[===================>]  55.76M  78.3MB/s    in 0.7s
#
# 2019-11-26 14:19:01 (78.3 MB/s) - ‘Miniconda3-4.5.4-Linux-x86_64.sh’ saved [58468498/58468498]
#
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# Python 3.6.5 :: Anaconda, Inc.
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# installing: ruamel_yaml-0.15.37-py36h14c3975_2 ...
# installing: six-1.11.0-py36h372c433_1 ...
# installing: cffi-1.11.5-py36h9745a5d_0 ...
# installing: setuptools-39.2.0-py36_0 ...
# installing: cryptography-2.2.2-py36h14c3975_0 ...
# installing: wheel-0.31.1-py36_0 ...
# installing: pip-10.0.1-py36_0 ...
# installing: pyopenssl-18.0.0-py36_0 ...
# installing: urllib3-1.22-py36hbe7ace6_0 ...
# installing: requests-2.18.4-py36he2e5f8d_1 ...
# installing: conda-4.5.4-py36_0 ...
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# Installing RAPIDS 0.10 packages
# Please standby, this will take a few minutes...
# Installing RAPIDS 0.10 packages from the stable release channel
# Please standby, this will take a few minutes...
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.4
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - cudatoolkit=10.1
#     - cudf=0.10
#     - cugraph
#     - cuml
#     - dask-cudf
#     - gcsfs
#     - pynvml
#     - python=3.6
#     - xgboost
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cachetools-3.1.1           |             py_0          11 KB  conda-forge
#     lz4-c-1.8.3                |    he1b5a44_1001         187 KB  conda-forge
#     python-dateutil-2.8.1      |             py_0         220 KB  conda-forge
#     gcsfs-0.4.0                |             py_0          19 KB  conda-forge
#     psutil-5.6.5               |   py36h516909a_0         325 KB  conda-forge
#     rsa-4.0                    |             py_0          27 KB  conda-forge
#     ca-certificates-2019.9.11  |       hecc5488_0         144 KB  conda-forge
#     sortedcontainers-2.1.0     |             py_0          25 KB  conda-forge
#     libllvm8-8.0.1             |       hc9558a2_0        23.2 MB  conda-forge
#     pillow-6.2.1               |   py36h6b7be26_0         639 KB  conda-forge
#     requests-2.22.0            |           py36_1          84 KB  conda-forge
#     libpng-1.6.37              |       hed695b0_0         343 KB  conda-forge
#     blinker-1.4                |             py_1          13 KB  conda-forge
#     re2-2019.11.01             |       he1b5a44_0         421 KB  conda-forge
#     libevent-2.1.10            |       h72c5cf5_0         1.3 MB  conda-forge
#     libcblas-3.8.0             |      14_openblas          10 KB  conda-forge
#     tblib-1.4.0                |             py_0          12 KB  conda-forge
#     scikit-learn-0.21.3        |   py36hcdab131_0         6.7 MB  conda-forge
#     jpeg-9c                    |    h14c3975_1001         251 KB  conda-forge
#     libnvstrings-0.10.0        |       cuda10.1_0        25.1 MB  rapidsai
#     pyjwt-1.7.1                |             py_0          17 KB  conda-forge
#     readline-8.0               |       hf8c457e_0         441 KB  conda-forge
#     markupsafe-1.1.1           |   py36h516909a_0          26 KB  conda-forge
#     pyasn1-modules-0.2.7       |             py_0          60 KB  conda-forge
#     setuptools-42.0.1          |           py36_0         633 KB  conda-forge
#     dask-cudf-0.10.0           |           py36_0          65 KB  rapidsai
#     libprotobuf-3.8.0          |       h8b12597_0         4.7 MB  conda-forge
#     libtiff-4.0.10             |    h57b8799_1003         587 KB  conda-forge
#     libcugraph-0.10.0          |       cuda10.1_0        16.1 MB  rapidsai
#     grpc-cpp-1.25.0            |       h18db393_0         5.1 MB  conda-forge
#     brotli-1.0.7               |    he1b5a44_1000         1.0 MB  conda-forge
#     google-auth-oauthlib-0.4.1 |             py_0          18 KB  conda-forge
#     six-1.13.0                 |           py36_0          22 KB  conda-forge
#     py-xgboost-0.90.rapidsdev1 |   cuda10.1py36_1          87 KB  rapidsai/label/xgboost
#     locket-0.2.0               |             py_2           6 KB  conda-forge
#     librmm-0.10.0              |       cuda10.1_0          50 KB  rapidsai
#     libblas-3.8.0              |      14_openblas          10 KB  conda-forge
#     libcuml-0.10.0             |       cuda10.1_0        40.6 MB  rapidsai
#     chardet-3.0.4              |        py36_1003         190 KB  conda-forge
#     libgfortran-ng-7.3.0       |       hdf63c60_2         1.7 MB  conda-forge
#     boost-cpp-1.70.0           |       h8e57a91_2        21.1 MB  conda-forge
#     oauthlib-3.0.1             |             py_0          82 KB  conda-forge
#     python-3.6.7               |    h357f687_1006        34.6 MB  conda-forge
#     bzip2-1.0.8                |       h516909a_1         397 KB  conda-forge
#     cudf-0.10.0                |           py36_0         7.2 MB  rapidsai
#     cudatoolkit-10.1.243       |       h6bb024c_0       513.2 MB  nvidia
#     xz-5.2.4                   |    h14c3975_1001         366 KB  conda-forge
#     tornado-6.0.3              |   py36h516909a_0         636 KB  conda-forge
#     pynvml-8.0.3               |             py_0          30 KB  conda-forge
#     google-auth-1.7.1          |             py_0          46 KB  conda-forge
#     wheel-0.33.6               |           py36_0          35 KB  conda-forge
#     glog-0.4.0                 |       he1b5a44_1         104 KB  conda-forge
#     xgboost-0.90.rapidsdev1    |   cuda10.1py36_1          12 KB  rapidsai/label/xgboost
#     zstd-1.4.0                 |       h3b9ef0a_0         928 KB  conda-forge
#     toolz-0.10.0               |             py_0          46 KB  conda-forge
#     _libgcc_mutex-0.1          |             main           3 KB
#     pyopenssl-19.0.0           |           py36_0          81 KB  conda-forge
#     arrow-cpp-0.14.1           |   py36h6b969ab_1        17.3 MB  conda-forge
#     cffi-1.13.2                |   py36h8022711_0         220 KB  conda-forge
#     requests-oauthlib-1.2.0    |             py_0          19 KB  conda-forge
#     gflags-2.2.2               |    he1b5a44_1002         175 KB  conda-forge
#     joblib-0.14.0              |             py_0         197 KB  conda-forge
#     libcumlprims-0.10.0        |       cuda10.1_0         4.2 MB  nvidia
#     pyyaml-5.1.2               |   py36h516909a_0         184 KB  conda-forge
#     pyarrow-0.14.1             |   py36h8b68381_2         2.8 MB  conda-forge
#     zlib-1.2.11                |    h516909a_1006         105 KB  conda-forge
#     cuml-0.10.0                |  cuda10.1_py36_0         6.6 MB  rapidsai
#     pytz-2019.3                |             py_0         237 KB  conda-forge
#     cytoolz-0.10.1             |   py36h516909a_0         431 KB  conda-forge
#     icu-64.2                   |       he1b5a44_1        12.6 MB  conda-forge
#     rmm-0.10.0                 |           py36_0         135 KB  rapidsai
#     fsspec-0.6.0               |             py_0          46 KB  conda-forge
#     fastavro-0.22.7            |   py36h516909a_0         404 KB  conda-forge
#     c-ares-1.15.0              |    h516909a_1001         100 KB  conda-forge
#     libopenblas-0.3.7          |       h6e990d7_3         7.6 MB  conda-forge
#     partd-1.0.0                |             py_0          16 KB  conda-forge
#     cryptography-2.8           |   py36h72c5cf5_0         626 KB  conda-forge
#     dask-2.8.1                 |             py_0           4 KB  conda-forge
#     thrift-cpp-0.12.0          |    hf3afdfd_1004         2.4 MB  conda-forge
#     libstdcxx-ng-9.1.0         |       hdf63c60_0         4.0 MB
#     msgpack-python-0.6.2       |   py36hc9558a2_0          89 KB  conda-forge
#     zict-1.0.0                 |             py_0          10 KB  conda-forge
#     nccl-2.4.6.1               |       cuda10.1_0        66.9 MB  nvidia
#     cugraph-0.10.0             |           py36_0         1.7 MB  rapidsai
#     dask-core-2.8.1            |             py_0         580 KB  conda-forge
#     libcudf-0.10.0             |       cuda10.1_0        32.3 MB  rapidsai
#     urllib3-1.25.7             |           py36_0         160 KB  conda-forge
#     pyparsing-2.4.5            |             py_0          58 KB  conda-forge
#     liblapack-3.8.0            |      14_openblas          10 KB  conda-forge
#     libffi-3.2.1               |    he1b5a44_1006          46 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     parquet-cpp-1.5.1          |                2           3 KB  conda-forge
#     freetype-2.10.0            |       he983fc9_1         884 KB  conda-forge
#     scipy-1.3.2                |   py36h921218d_0        18.0 MB  conda-forge
#     cloudpickle-1.2.2          |             py_1          23 KB  conda-forge
#     pandas-0.24.2              |   py36hb3f55d8_1        11.1 MB  conda-forge
#     heapdict-1.0.1             |             py_0           7 KB  conda-forge
#     tk-8.6.10                  |       hed695b0_0         3.2 MB  conda-forge
#     pysocks-1.7.1              |           py36_0          27 KB  conda-forge
#     libxgboost-0.90.rapidsdev1 |       cuda10.1_1        33.2 MB  rapidsai/label/xgboost
#     decorator-4.4.1            |             py_0          11 KB  conda-forge
#     distributed-2.8.1          |             py_0         393 KB  conda-forge
#     nvstrings-0.10.0           |           py36_0         126 KB  rapidsai
#     pip-19.3.1                 |           py36_0         1.9 MB  conda-forge
#     double-conversion-3.1.5    |       he1b5a44_2          85 KB  conda-forge
#     cython-0.29.14             |   py36he1b5a44_0         2.2 MB  conda-forge
#     certifi-2019.9.11          |           py36_0         147 KB  conda-forge
#     ncurses-6.1                |    hf484d3e_1002         1.3 MB  conda-forge
#     snappy-1.1.7               |    he1b5a44_1002          39 KB  conda-forge
#     packaging-19.2             |             py_0          27 KB  conda-forge
#     uriparser-0.9.3            |       he1b5a44_1          49 KB  conda-forge
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB
#     dlpack-0.2                 |       he1b5a44_1          13 KB  conda-forge
#     pyasn1-0.4.8               |             py_0          53 KB  conda-forge
#     numpy-1.17.3               |   py36h95a1406_0         5.2 MB  conda-forge
#     idna-2.8                   |        py36_1000         132 KB  conda-forge
#     bokeh-1.4.0                |           py36_0        13.5 MB  conda-forge
#     numba-0.46.0               |   py36hb3f55d8_1         3.3 MB  conda-forge
#     click-7.0                  |             py_0          61 KB  conda-forge
#     sqlite-3.30.1              |       hcee41ef_0         2.0 MB  conda-forge
#     llvmlite-0.30.0            |   py36h8b12597_1         337 KB  conda-forge
#     pycparser-2.19             |           py36_1         173 KB  conda-forge
#     olefile-0.46               |             py_0          31 KB  conda-forge
#     yaml-0.1.7                 |    h14c3975_1001          78 KB  conda-forge
#     jinja2-2.10.3              |             py_0          91 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       979.3 MB
#
# The following NEW packages will be INSTALLED:
#
#     _libgcc_mutex:        0.1-main
#     arrow-cpp:            0.14.1-py36h6b969ab_1          conda-forge
#     blinker:              1.4-py_1                       conda-forge
#     bokeh:                1.4.0-py36_0                   conda-forge
#     boost-cpp:            1.70.0-h8e57a91_2              conda-forge
#     brotli:               1.0.7-he1b5a44_1000            conda-forge
#     bzip2:                1.0.8-h516909a_1               conda-forge
#     c-ares:               1.15.0-h516909a_1001           conda-forge
#     cachetools:           3.1.1-py_0                     conda-forge
#     click:                7.0-py_0                       conda-forge
#     cloudpickle:          1.2.2-py_1                     conda-forge
#     cudatoolkit:          10.1.243-h6bb024c_0            nvidia
#     cudf:                 0.10.0-py36_0                  rapidsai
#     cugraph:              0.10.0-py36_0                  rapidsai
#     cuml:                 0.10.0-cuda10.1_py36_0         rapidsai
#     cython:               0.29.14-py36he1b5a44_0         conda-forge
#     cytoolz:              0.10.1-py36h516909a_0          conda-forge
#     dask:                 2.8.1-py_0                     conda-forge
#     dask-core:            2.8.1-py_0                     conda-forge
#     dask-cudf:            0.10.0-py36_0                  rapidsai
#     decorator:            4.4.1-py_0                     conda-forge
#     distributed:          2.8.1-py_0                     conda-forge
#     dlpack:               0.2-he1b5a44_1                 conda-forge
#     double-conversion:    3.1.5-he1b5a44_2               conda-forge
#     fastavro:             0.22.7-py36h516909a_0          conda-forge
#     freetype:             2.10.0-he983fc9_1              conda-forge
#     fsspec:               0.6.0-py_0                     conda-forge
#     gcsfs:                0.4.0-py_0                     conda-forge
#     gflags:               2.2.2-he1b5a44_1002            conda-forge
#     glog:                 0.4.0-he1b5a44_1               conda-forge
#     google-auth:          1.7.1-py_0                     conda-forge
#     google-auth-oauthlib: 0.4.1-py_0                     conda-forge
#     grpc-cpp:             1.25.0-h18db393_0              conda-forge
#     heapdict:             1.0.1-py_0                     conda-forge
#     icu:                  64.2-he1b5a44_1                conda-forge
#     jinja2:               2.10.3-py_0                    conda-forge
#     joblib:               0.14.0-py_0                    conda-forge
#     jpeg:                 9c-h14c3975_1001               conda-forge
#     libblas:              3.8.0-14_openblas              conda-forge
#     libcblas:             3.8.0-14_openblas              conda-forge
#     libcudf:              0.10.0-cuda10.1_0              rapidsai
#     libcugraph:           0.10.0-cuda10.1_0              rapidsai
#     libcuml:              0.10.0-cuda10.1_0              rapidsai
#     libcumlprims:         0.10.0-cuda10.1_0              nvidia
#     libevent:             2.1.10-h72c5cf5_0              conda-forge
#     libgfortran-ng:       7.3.0-hdf63c60_2               conda-forge
#     liblapack:            3.8.0-14_openblas              conda-forge
#     libllvm8:             8.0.1-hc9558a2_0               conda-forge
#     libnvstrings:         0.10.0-cuda10.1_0              rapidsai
#     libopenblas:          0.3.7-h6e990d7_3               conda-forge
#     libpng:               1.6.37-hed695b0_0              conda-forge
#     libprotobuf:          3.8.0-h8b12597_0               conda-forge
#     librmm:               0.10.0-cuda10.1_0              rapidsai
#     libtiff:              4.0.10-h57b8799_1003           conda-forge
#     libxgboost:           0.90.rapidsdev1-cuda10.1_1     rapidsai/label/xgboost
#     llvmlite:             0.30.0-py36h8b12597_1          conda-forge
#     locket:               0.2.0-py_2                     conda-forge
#     lz4-c:                1.8.3-he1b5a44_1001            conda-forge
#     markupsafe:           1.1.1-py36h516909a_0           conda-forge
#     msgpack-python:       0.6.2-py36hc9558a2_0           conda-forge
#     nccl:                 2.4.6.1-cuda10.1_0             nvidia
#     numba:                0.46.0-py36hb3f55d8_1          conda-forge
#     numpy:                1.17.3-py36h95a1406_0          conda-forge
#     nvstrings:            0.10.0-py36_0                  rapidsai
#     oauthlib:             3.0.1-py_0                     conda-forge
#     olefile:              0.46-py_0                      conda-forge
#     packaging:            19.2-py_0                      conda-forge
#     pandas:               0.24.2-py36hb3f55d8_1          conda-forge
#     parquet-cpp:          1.5.1-2                        conda-forge
#     partd:                1.0.0-py_0                     conda-forge
#     pillow:               6.2.1-py36h6b7be26_0           conda-forge
#     psutil:               5.6.5-py36h516909a_0           conda-forge
#     py-xgboost:           0.90.rapidsdev1-cuda10.1py36_1 rapidsai/label/xgboost
#     pyarrow:              0.14.1-py36h8b68381_2          conda-forge
#     pyasn1:               0.4.8-py_0                     conda-forge
#     pyasn1-modules:       0.2.7-py_0                     conda-forge
#     pyjwt:                1.7.1-py_0                     conda-forge
#     pynvml:               8.0.3-py_0                     conda-forge
#     pyparsing:            2.4.5-py_0                     conda-forge
#     python-dateutil:      2.8.1-py_0                     conda-forge
#     pytz:                 2019.3-py_0                    conda-forge
#     pyyaml:               5.1.2-py36h516909a_0           conda-forge
#     re2:                  2019.11.01-he1b5a44_0          conda-forge
#     requests-oauthlib:    1.2.0-py_0                     conda-forge
#     rmm:                  0.10.0-py36_0                  rapidsai
#     rsa:                  4.0-py_0                       conda-forge
#     scikit-learn:         0.21.3-py36hcdab131_0          conda-forge
#     scipy:                1.3.2-py36h921218d_0           conda-forge
#     snappy:               1.1.7-he1b5a44_1002            conda-forge
#     sortedcontainers:     2.1.0-py_0                     conda-forge
#     tblib:                1.4.0-py_0                     conda-forge
#     thrift-cpp:           0.12.0-hf3afdfd_1004           conda-forge
#     toolz:                0.10.0-py_0                    conda-forge
#     tornado:              6.0.3-py36h516909a_0           conda-forge
#     uriparser:            0.9.3-he1b5a44_1               conda-forge
#     xgboost:              0.90.rapidsdev1-cuda10.1py36_1 rapidsai/label/xgboost
#     zict:                 1.0.0-py_0                     conda-forge
#     zstd:                 1.4.0-h3b9ef0a_0               conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates:      2018.03.07-0                                          --> 2019.9.11-hecc5488_0  conda-forge
#     certifi:              2018.4.16-py36_0                                      --> 2019.9.11-py36_0      conda-forge
#     cffi:                 1.11.5-py36h9745a5d_0                                 --> 1.13.2-py36h8022711_0 conda-forge
#     chardet:              3.0.4-py36h0f667ec_1                                  --> 3.0.4-py36_1003       conda-forge
#     cryptography:         2.2.2-py36h14c3975_0                                  --> 2.8-py36h72c5cf5_0    conda-forge
#     idna:                 2.6-py36h82fb2a8_1                                    --> 2.8-py36_1000         conda-forge
#     libffi:               3.2.1-hd88cf55_4                                      --> 3.2.1-he1b5a44_1006   conda-forge
#     libgcc-ng:            7.2.0-hdf63c60_3                                      --> 9.1.0-hdf63c60_0
#     libstdcxx-ng:         7.2.0-hdf63c60_3                                      --> 9.1.0-hdf63c60_0
#     ncurses:              6.1-hf484d3e_0                                        --> 6.1-hf484d3e_1002     conda-forge
#     openssl:              1.0.2o-h20670df_0                                     --> 1.1.1d-h516909a_0     conda-forge
#     pip:                  10.0.1-py36_0                                         --> 19.3.1-py36_0         conda-forge
#     pycparser:            2.18-py36hf9f622e_1                                   --> 2.19-py36_1           conda-forge
#     pyopenssl:            18.0.0-py36_0                                         --> 19.0.0-py36_0         conda-forge
#     pysocks:              1.6.8-py36_0                                          --> 1.7.1-py36_0          conda-forge
#     python:               3.6.5-hc3d631a_2                                      --> 3.6.7-h357f687_1006   conda-forge
#     readline:             7.0-ha6073c6_4                                        --> 8.0-hf8c457e_0        conda-forge
#     requests:             2.18.4-py36he2e5f8d_1                                 --> 2.22.0-py36_1         conda-forge
#     setuptools:           39.2.0-py36_0                                         --> 42.0.1-py36_0         conda-forge
#     six:                  1.11.0-py36h372c433_1                                 --> 1.13.0-py36_0         conda-forge
#     sqlite:               3.23.1-he433501_0                                     --> 3.30.1-hcee41ef_0     conda-forge
#     tk:                   8.6.7-hc745277_3                                      --> 8.6.10-hed695b0_0     conda-forge
#     urllib3:              1.22-py36hbe7ace6_0                                   --> 1.25.7-py36_0         conda-forge
#     wheel:                0.31.1-py36_0                                         --> 0.33.6-py36_0         conda-forge
#     xz:                   5.2.4-h14c3975_4                                      --> 5.2.4-h14c3975_1001   conda-forge
#     yaml:                 0.1.7-had09818_2                                      --> 0.1.7-h14c3975_1001   conda-forge
#     zlib:                 1.2.11-ha838bed_2                                     --> 1.2.11-h516909a_1006  conda-forge
#
#
# Downloading and Extracting Packages
# cachetools-3.1.1     |   11 KB | : 100% 1.0/1 [00:00<00:00, 19.35it/s]
# lz4-c-1.8.3          |  187 KB | : 100% 1.0/1 [00:00<00:00, 10.30it/s]
# python-dateutil-2.8. |  220 KB | : 100% 1.0/1 [00:00<00:00, 16.18it/s]
# gcsfs-0.4.0          |   19 KB | : 100% 1.0/1 [00:00<00:00, 31.26it/s]
# psutil-5.6.5         |  325 KB | : 100% 1.0/1 [00:00<00:00,  9.28it/s]
# rsa-4.0              |   27 KB | : 100% 1.0/1 [00:00<00:00, 22.47it/s]
# ca-certificates-2019 |  144 KB | : 100% 1.0/1 [00:00<00:00, 23.89it/s]
# sortedcontainers-2.1 |   25 KB | : 100% 1.0/1 [00:00<00:00, 28.96it/s]
# libllvm8-8.0.1       | 23.2 MB | : 100% 1.0/1 [00:03<00:00,  3.39s/it]
# pillow-6.2.1         |  639 KB | : 100% 1.0/1 [00:00<00:00,  6.03it/s]
# requests-2.22.0      |   84 KB | : 100% 1.0/1 [00:00<00:00, 16.81it/s]
# libpng-1.6.37        |  343 KB | : 100% 1.0/1 [00:00<00:00, 11.09it/s]
# blinker-1.4          |   13 KB | : 100% 1.0/1 [00:00<00:00, 22.31it/s]
# re2-2019.11.01       |  421 KB | : 100% 1.0/1 [00:00<00:00,  7.64it/s]
# libevent-2.1.10      |  1.3 MB | : 100% 1.0/1 [00:00<00:00,  2.49it/s]
# libcblas-3.8.0       |   10 KB | : 100% 1.0/1 [00:00<00:00, 12.18it/s]
# tblib-1.4.0          |   12 KB | : 100% 1.0/1 [00:00<00:00, 31.73it/s]
# scikit-learn-0.21.3  |  6.7 MB | : 100% 1.0/1 [00:02<00:00,  2.93s/it]
# jpeg-9c              |  251 KB | : 100% 1.0/1 [00:00<00:00, 13.92it/s]
# libnvstrings-0.10.0  | 25.1 MB | : 100% 1.0/1 [00:06<00:00,  6.58s/it]
# pyjwt-1.7.1          |   17 KB | : 100% 1.0/1 [00:00<00:00, 28.93it/s]
# readline-8.0         |  441 KB | : 100% 1.0/1 [00:00<00:00,  8.51it/s]
# markupsafe-1.1.1     |   26 KB | : 100% 1.0/1 [00:00<00:00, 20.45it/s]
# pyasn1-modules-0.2.7 |   60 KB | : 100% 1.0/1 [00:00<00:00,  8.10it/s]
# setuptools-42.0.1    |  633 KB | : 100% 1.0/1 [00:00<00:00,  5.11it/s]
# dask-cudf-0.10.0     |   65 KB | : 100% 1.0/1 [00:00<00:00,  2.86it/s]
# libprotobuf-3.8.0    |  4.7 MB | : 100% 1.0/1 [00:00<00:00,  1.13it/s]
# libtiff-4.0.10       |  587 KB | : 100% 1.0/1 [00:00<00:00,  7.59it/s]
# libcugraph-0.10.0    | 16.1 MB | : 100% 1.0/1 [00:03<00:00,  3.57s/it]
# grpc-cpp-1.25.0      |  5.1 MB | : 100% 1.0/1 [00:00<00:00,  1.00it/s]
# brotli-1.0.7         |  1.0 MB | : 100% 1.0/1 [00:00<00:00,  6.21it/s]
# google-auth-oauthlib |   18 KB | : 100% 1.0/1 [00:00<00:00, 25.57it/s]
# six-1.13.0           |   22 KB | : 100% 1.0/1 [00:00<00:00, 32.10it/s]
# py-xgboost-0.90.rapi |   87 KB | : 100% 1.0/1 [00:00<00:00,  1.18it/s]
# locket-0.2.0         |    6 KB | : 100% 1.0/1 [00:00<00:00, 37.24it/s]
# librmm-0.10.0        |   50 KB | : 100% 1.0/1 [00:00<00:00,  3.17it/s]
# libblas-3.8.0        |   10 KB | : 100% 1.0/1 [00:00<00:00, 30.82it/s]
# libcuml-0.10.0       | 40.6 MB | : 100% 1.0/1 [00:08<00:00,  8.95s/it]
# chardet-3.0.4        |  190 KB | : 100% 1.0/1 [00:00<00:00,  6.81it/s]
# libgfortran-ng-7.3.0 |  1.7 MB | : 100% 1.0/1 [00:00<00:00,  3.65it/s]
# boost-cpp-1.70.0     | 21.1 MB | : 100% 1.0/1 [00:08<00:00,  8.14s/it]
# oauthlib-3.0.1       |   82 KB | : 100% 1.0/1 [00:00<00:00, 15.66it/s]
# python-3.6.7         | 34.6 MB | : 100% 1.0/1 [00:04<00:00,  4.65s/it]
# bzip2-1.0.8          |  397 KB | : 100% 1.0/1 [00:00<00:00,  9.55it/s]
# cudf-0.10.0          |  7.2 MB | : 100% 1.0/1 [00:02<00:00,  2.88s/it]
# cudatoolkit-10.1.243 | 513.2 MB | : 100% 1.0/1 [01:10<00:00, 70.96s/it]
# xz-5.2.4             |  366 KB | : 100% 1.0/1 [00:00<00:00,  8.25it/s]
# tornado-6.0.3        |  636 KB | : 100% 1.0/1 [00:00<00:00,  4.91it/s]
# pynvml-8.0.3         |   30 KB | : 100% 1.0/1 [00:00<00:00, 19.80it/s]
# google-auth-1.7.1    |   46 KB | : 100% 1.0/1 [00:00<00:00, 20.21it/s]
# wheel-0.33.6         |   35 KB | : 100% 1.0/1 [00:00<00:00, 24.60it/s]
# glog-0.4.0           |  104 KB | : 100% 1.0/1 [00:00<00:00, 16.50it/s]
# xgboost-0.90.rapidsd |   12 KB | : 100% 1.0/1 [00:01<00:00,  1.16s/it]
# zstd-1.4.0           |  928 KB | : 100% 1.0/1 [00:00<00:00,  6.46it/s]
# toolz-0.10.0         |   46 KB | : 100% 1.0/1 [00:00<00:00, 21.38it/s]
# _libgcc_mutex-0.1    |    3 KB | : 100% 1.0/1 [00:00<00:00, 18.93it/s]
# pyopenssl-19.0.0     |   81 KB | : 100% 1.0/1 [00:00<00:00, 19.59it/s]
# arrow-cpp-0.14.1     | 17.3 MB | : 100% 1.0/1 [00:02<00:00,  2.61s/it]
# cffi-1.13.2          |  220 KB | : 100% 1.0/1 [00:00<00:00,  7.96it/s]
# requests-oauthlib-1. |   19 KB | : 100% 1.0/1 [00:00<00:00, 25.38it/s]
# gflags-2.2.2         |  175 KB | : 100% 1.0/1 [00:00<00:00, 13.10it/s]
# joblib-0.14.0        |  197 KB | : 100% 1.0/1 [00:00<00:00,  8.81it/s]
# libcumlprims-0.10.0  |  4.2 MB | : 100% 1.0/1 [00:01<00:00,  1.87s/it]
# pyyaml-5.1.2         |  184 KB | : 100% 1.0/1 [00:00<00:00, 15.28it/s]
# pyarrow-0.14.1       |  2.8 MB | : 100% 1.0/1 [00:00<00:00,  1.35it/s]
# zlib-1.2.11          |  105 KB | : 100% 1.0/1 [00:00<00:00, 22.75it/s]
# cuml-0.10.0          |  6.6 MB | : 100% 1.0/1 [00:01<00:00,  1.86s/it]
# pytz-2019.3          |  237 KB | : 100% 1.0/1 [00:00<00:00,  5.25it/s]
# cytoolz-0.10.1       |  431 KB | : 100% 1.0/1 [00:00<00:00,  9.34it/s]
# icu-64.2             | 12.6 MB | : 100% 1.0/1 [00:01<00:00,  1.80s/it]
# rmm-0.10.0           |  135 KB | : 100% 1.0/1 [00:00<00:00,  1.21it/s]
# fsspec-0.6.0         |   46 KB | : 100% 1.0/1 [00:00<00:00, 22.75it/s]
# fastavro-0.22.7      |  404 KB | : 100% 1.0/1 [00:00<00:00,  9.89it/s]
# c-ares-1.15.0        |  100 KB | : 100% 1.0/1 [00:00<00:00, 24.16it/s]
# libopenblas-0.3.7    |  7.6 MB | : 100% 1.0/1 [00:01<00:00,  1.20s/it]
# partd-1.0.0          |   16 KB | : 100% 1.0/1 [00:00<00:00, 27.30it/s]
# cryptography-2.8     |  626 KB | : 100% 1.0/1 [00:00<00:00,  5.10it/s]
# dask-2.8.1           |    4 KB | : 100% 1.0/1 [00:00<00:00, 23.76it/s]
# thrift-cpp-0.12.0    |  2.4 MB | : 100% 1.0/1 [00:00<00:00,  2.28it/s]
# libstdcxx-ng-9.1.0   |  4.0 MB | : 100% 1.0/1 [00:00<00:00,  1.78it/s]
# msgpack-python-0.6.2 |   89 KB | : 100% 1.0/1 [00:00<00:00, 21.29it/s]
# zict-1.0.0           |   10 KB | : 100% 1.0/1 [00:00<00:00, 28.83it/s]
# nccl-2.4.6.1         | 66.9 MB | : 100% 1.0/1 [00:10<00:00, 10.19s/it]
# cugraph-0.10.0       |  1.7 MB | : 100% 1.0/1 [00:01<00:00,  1.85s/it]
# dask-core-2.8.1      |  580 KB | : 100% 1.0/1 [00:00<00:00,  5.37it/s]
# libcudf-0.10.0       | 32.3 MB | : 100% 1.0/1 [00:06<00:00,  6.82s/it]
# urllib3-1.25.7       |  160 KB | : 100% 1.0/1 [00:00<00:00, 13.09it/s]
# pyparsing-2.4.5      |   58 KB | : 100% 1.0/1 [00:00<00:00, 20.88it/s]
# liblapack-3.8.0      |   10 KB | : 100% 1.0/1 [00:00<00:00, 31.86it/s]
# libffi-3.2.1         |   46 KB | : 100% 1.0/1 [00:00<00:00, 24.84it/s]
# openssl-1.1.1d       |  2.1 MB | : 100% 1.0/1 [00:00<00:00,  2.83it/s]
# parquet-cpp-1.5.1    |    3 KB | : 100% 1.0/1 [00:00<00:00, 36.60it/s]
# freetype-2.10.0      |  884 KB | : 100% 1.0/1 [00:00<00:00,  6.24it/s]
# scipy-1.3.2          | 18.0 MB | : 100% 1.0/1 [00:02<00:00,  2.92s/it]
# cloudpickle-1.2.2    |   23 KB | : 100% 1.0/1 [00:00<00:00, 27.13it/s]
# pandas-0.24.2        | 11.1 MB | : 100% 1.0/1 [00:02<00:00,  2.23s/it]
# heapdict-1.0.1       |    7 KB | : 100% 1.0/1 [00:00<00:00, 31.74it/s]
# tk-8.6.10            |  3.2 MB | : 100% 1.0/1 [00:00<00:00,  1.69it/s]
# pysocks-1.7.1        |   27 KB | : 100% 1.0/1 [00:00<00:00, 23.43it/s]
# libxgboost-0.90.rapi | 33.2 MB | : 100% 1.0/1 [00:08<00:00,  8.82s/it]
# decorator-4.4.1      |   11 KB | : 100% 1.0/1 [00:00<00:00, 27.54it/s]
# distributed-2.8.1    |  393 KB | : 100% 1.0/1 [00:00<00:00,  6.69it/s]
# nvstrings-0.10.0     |  126 KB | : 100% 1.0/1 [00:00<00:00,  1.26it/s]
# pip-19.3.1           |  1.9 MB | : 100% 1.0/1 [00:00<00:00,  1.96it/s]
# double-conversion-3. |   85 KB | : 100% 1.0/1 [00:00<00:00, 21.24it/s]
# cython-0.29.14       |  2.2 MB | : 100% 1.0/1 [00:00<00:00,  2.03it/s]
# certifi-2019.9.11    |  147 KB | : 100% 1.0/1 [00:00<00:00, 20.79it/s]
# ncurses-6.1          |  1.3 MB | : 100% 1.0/1 [00:00<00:00,  1.13it/s]
# snappy-1.1.7         |   39 KB | : 100% 1.0/1 [00:00<00:00, 17.84it/s]
# packaging-19.2       |   27 KB | : 100% 1.0/1 [00:00<00:00, 17.95it/s]
# uriparser-0.9.3      |   49 KB | : 100% 1.0/1 [00:00<00:00, 14.44it/s]
# libgcc-ng-9.1.0      |  8.1 MB | : 100% 1.0/1 [00:01<00:00,  1.11s/it]
# dlpack-0.2           |   13 KB | : 100% 1.0/1 [00:00<00:00, 30.61it/s]
# pyasn1-0.4.8         |   53 KB | : 100% 1.0/1 [00:00<00:00, 20.11it/s]
# numpy-1.17.3         |  5.2 MB | : 100% 1.0/1 [00:01<00:00,  1.11s/it]
# idna-2.8             |  132 KB | : 100% 1.0/1 [00:00<00:00, 17.53it/s]
# bokeh-1.4.0          | 13.5 MB | : 100% 1.0/1 [00:03<00:00,  3.91s/it]
# numba-0.46.0         |  3.3 MB | : 100% 1.0/1 [00:00<00:00,  1.11it/s]
# click-7.0            |   61 KB | : 100% 1.0/1 [00:00<00:00,  6.27it/s]
# sqlite-3.30.1        |  2.0 MB | : 100% 1.0/1 [00:00<00:00,  3.46it/s]
# llvmlite-0.30.0      |  337 KB | : 100% 1.0/1 [00:00<00:00, 10.01it/s]
# pycparser-2.19       |  173 KB | : 100% 1.0/1 [00:00<00:00, 14.43it/s]
# olefile-0.46         |   31 KB | : 100% 1.0/1 [00:00<00:00, 28.35it/s]
# yaml-0.1.7           |   78 KB | : 100% 1.0/1 [00:00<00:00, 11.37it/s]
# jinja2-2.10.3        |   91 KB | : 100% 1.0/1 [00:00<00:00, 13.96it/s]
# done
# done
# done
# Copying shared object files to /usr/lib
#
# *********************************************
# Your Google Colab instance is RAPIDS ready!
# *********************************************

# %% [markdown]
# # cuDF and cuML Examples #
#
# Now you can run code!
#
# What follows are basic examples where all processing takes place on the GPU.

# %% [markdown]
# #[cuDF](https://github.com/rapidsai/cudf)#
#
# Load a dataset into a GPU memory resident DataFrame and perform a basic calculation.
#
# Everything from CSV parsing to calculating tip percentage and computing a grouped average is done on the GPU.
#
# _Note_: You must import nvstrings and nvcategory before cudf, else you'll get errors.

# %%
import cudf
import io, requests

# download CSV file from GitHub
url="https://github.com/plotly/datasets/raw/master/tips.csv"
content = requests.get(url).content.decode('utf-8')

# read CSV from memory
tips_df = cudf.read_csv(io.StringIO(content))
tips_df['tip_percentage'] = tips_df['tip']/tips_df['total_bill']*100

# display average tip by dining party size
print(tips_df.groupby('size').tip_percentage.mean())
# Out:
# size
# 1    21.729202
# 2    16.571919
# 3    15.215685
# 4    14.594901
# 5    14.149549
# 6    15.622920
# Name: tip_percentage, dtype: float64

# %% [markdown]
# #[cuML](https://github.com/rapidsai/cuml)#
#
# This snippet loads a
#
# As above, all calculations are performed on the GPU.

# %%
import cuml

# Create and populate a GPU DataFrame
df_float = cudf.DataFrame()
df_float['0'] = [1.0, 2.0, 5.0]
df_float['1'] = [4.0, 2.0, 1.0]
df_float['2'] = [4.0, 2.0, 1.0]

# Setup and fit clusters
dbscan_float = cuml.DBSCAN(eps=1.0, min_samples=1)
dbscan_float.fit(df_float)

print(dbscan_float.labels_)
# Out:
# 0    0
# 1    1
# 2    2
# dtype: int32

# %% [markdown]
# # Next Steps #
#
# For an overview of how you can access and work with your own datasets in Colab, check out [this guide](https://towardsdatascience.com/3-ways-to-load-csv-files-into-colab-7c14fcbdcb92).
#
# For more RAPIDS examples, check out our RAPIDS notebooks repos:
# 1. https://github.com/rapidsai/notebooks
# 2. https://github.com/rapidsai/notebooks-contrib
